# %% [markdown]
# # Table driven agent

# %% [markdown]
# Vaccum Cleaning Agent with locations A and B

# %%
# how many sensors? Ans: 2 (Location and, Condition)
# Location -> A or B
# Condition -> clean or dirty
# how many different perecept sequences? Ans: 4 (A,Clean) (A,Dirty) 
# ... (B,Clean) (B,Dirty)
# how many actions and what are the actions? 3 (Right, Left, and Suck)
# AGENT FUNCTION: map the percept sequences to actions

table={('A','Clean'):'Right',
       ('A','Dirty'):'Suck',
       ('B','Clean'):'Left',
       ('B','Dirty'):'Suck'}

percepts=[]  # to store percet sequence  
def table_driven_agent(percept):
    print('Perception Received: '+ str(percept))
    percepts.append(percept) # updating percept history
    action = lookup(percept,table) # searching for action
    return action

def lookup(percept,table):
    #for key in table:
    #    if key == percept:
    #        return table[key]
    return table[percept]

# lets simulate the agent
import random
Location = random.choice(['A','B'])
Condition = random.choice(['Clean','Dirty'])

while True: # to perceieve environment repeatedly
    action = table_driven_agent((Location, Condition))
    print('Action Performed: '+ action)
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Clean','Dirty'])
    elif action == 'Left':
        Location = 'A'
        Condition = random.choice(['Clean','Dirty'])
    else:
        Condition = 'Clean'
# Out:
# Perception Received: ('A', 'Dirty')
# Action Performed: Suck
# Get Perception (yes/no): yes
# Perception Received: ('A', 'Clean')
# Action Performed: Right
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Dirty')
# Action Performed: Suck
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Clean')
# Action Performed: Left
# Get Perception (yes/no): yes
# Perception Received: ('A', 'Clean')
# Action Performed: Right
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Clean')
# Action Performed: Left
# Get Perception (yes/no): no

# %% [markdown]
# # Simple reflex agent

# %%
def simple_reflex_agent(percept):
    print('Perception Received: '+ str(percept))
    location = percept[0]
    status = percept[1]
    if status =='Dirty':
        action = 'Suck'
    elif location == 'A':
        action = 'Right'
    elif location =='B':
        action = 'Left'
    return action

import random
Location = random.choice(['A','B'])
Condition = random.choice(['Clean','Dirty'])

while True:
    action= simple_reflex_agent((Location,Condition))
    print('Action Performed: '+ action)
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Clean','Dirty'])
    elif action== 'Left':
        Location = 'A'
        Condition = random.choice(['Clean','Dirty'])
    else:
        Condition = 'Clean'
# Out:
# Perception Received: ('B', 'Dirty')
# Action Performed: Suck
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Clean')
# Action Performed: Left
# Get Perception (yes/no): yes
# Perception Received: ('A', 'Dirty')
# Action Performed: Suck
# Get Perception (yes/no): no

# %% [markdown]
# # Model based agent

# %%
model = {'A':'Unknown', 'B':'Unknown'}
world_state = 'Bad'
action = 'Unknown'

def update_state(action, percept, model):
    location = percept[0]
    status = percept[1]
    model[location] = status #udate the model based on current perception
    
    global world_state
    if action == 'Suck':
        model[location]='Clean'
    if model['A']=='Clean' and model['B']=='Clean': # model checking
        world_state = 'Good'
    else:
        world_state = 'Bad'
    return world_state
        

def model_based_reflex_agent(percept):
    location = percept[0]
    status = percept[1]
    
    global world_state,action,model
    
    if world_state == 'Good':
        action = 'Pause'
        return action
    elif status == 'Dirty':
        action = 'Suck'
    elif location == 'A':
        action = 'Right'
    elif location == 'B':
        action = 'Left'
    world_state = update_state(action, percept, model)
    print('Perception: '+str(percept)) 
    print('Action Performed: '+ action)    
    print('Model: '+str(model))   
    print('State: '+str(world_state))    
    return action


import random
Location = random.choice(['A','B'])
Condition= random.choice(['Clean','Dirty'])

while True:
    print('*****')
    action = model_based_reflex_agent((Location,Condition))
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Clean','Dirty'])
    elif action == 'Left':
        Location = 'A'
        Condition = random.choice(['Clean','Dirty'])
    elif action == 'Suck':
        Condition = 'Clean'
    elif action == 'Pause':
        cmd = input('Stopped. Do restart? (yes/no): ')
        if(cmd == 'no' or cmd != 'yes'): break
        Location = random.choice(['A','B'])
        Condition = random.choice(['Clean','Dirty'])
        model = {'A':'Unknown', 'B':'Unknown'}
        world_state = 'Bad'
        action = 'Unknown'
# Out:
# *****
# Perception: ('A', 'Clean')
# Action Performed: Right
# Model: {'A': 'Clean', 'B': 'Unknown'}
# State: Bad
# *****
# Perception: ('B', 'Dirty')
# Action Performed: Suck
# Model: {'A': 'Clean', 'B': 'Clean'}
# State: Good
# *****
# Stopped. Do restart? (yes/no): yes
# *****
# Perception: ('B', 'Dirty')
# Action Performed: Suck
# Model: {'A': 'Unknown', 'B': 'Clean'}
# State: Bad
# *****
# Perception: ('B', 'Clean')
# Action Performed: Left
# Model: {'A': 'Unknown', 'B': 'Clean'}
# State: Bad
# *****
# Perception: ('A', 'Dirty')
# Action Performed: Suck
# Model: {'A': 'Clean', 'B': 'Clean'}
# State: Good
# *****
# Stopped. Do restart? (yes/no): no

# %% [markdown]
# ## Task

# %% [markdown]
# Implement diffierent types of agent implementation to do certain task of your choice.
# 1. Table Driven Agent
# 2. Simple Reflex Agent
# 3. Model Based Agent

# %% [markdown]
# Road Making Agent
# PEAS desription:
#
#  PEAS MEANS Performance, Environment, Actuators, Sensors
#
#
#
# Agent Description:
# The aim of the agent is anything that can be viewed as
# perceiving its environment through sensors and
# acting upon that environment through actuators
#
# List the actions:Left,Right,carpeting
#
# List the sensors:Location and maker
# Agent function:  map the percept sequences to actions

# %% [markdown]
# # Road Making Agent

# %% [markdown]
# # Table driven agent

# %%
table={('A','Making'):'Right',
       ('A','Broken'):'Carpeting',
       ('B','Making'):'Left',
       ('B','Broken'):'Carpeting'}

percepts=[]  # to store percet sequence  
def table_driven_agent(percept):
    print('Perception Received: '+ str(percept))
    percepts.append(percept) # updating percept history
    action = lookup(percept,table) # searching for action
    return action

def lookup(percept,table):
    #for key in table:
    #    if key == percept:
    #        return table[key]
    return table[percept]

# lets simulate the agent
import random
Location = random.choice(['A','B'])
Condition = random.choice(['Making','Broken'])

while True: # to perceieve environment repeatedly
    action = table_driven_agent((Location, Condition))
    print('Action Performed: '+ action)
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Making','Broken'])
    elif action == 'Left':
        Location = 'A'
        Condition = random.choice(['Making','Broken'])
    else:
        Condition = 'Making'
# Out:
# Perception Received: ('B', 'Making')
# Action Performed: Left
# Get Perception (yes/no): yes
# Perception Received: ('A', 'Making')
# Action Performed: Right
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Broken')
# Action Performed: Carpeting
# Get Perception (yes/no): no

# %% [markdown]
# # Simple reflex agent

# %%
def simple_reflex_agent(percept):
    print('Perception Received: '+ str(percept))
    location = percept[0]
    status = percept[1]
    if status =='Broken':
        action = 'Carpeting'
    elif location == 'A':
        action = 'Right'
    elif location =='B':
        action = 'Left'
    return action

import random
Location = random.choice(['A','B'])
Condition = random.choice(['Making','Broken'])

while True:
    action= simple_reflex_agent((Location,Condition))
    print('Action Performed: '+ action)
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Making','Broken'])
    elif action== 'Left':
        Location = 'A'
        Condition = random.choice(['Making','Broken'])
    else:
        Condition = 'Making'
# Out:
# Perception Received: ('A', 'Making')
# Action Performed: Right
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Broken')
# Action Performed: Carpeting
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Making')
# Action Performed: Left
# Get Perception (yes/no): yes
# Perception Received: ('A', 'Broken')
# Action Performed: Carpeting
# Get Perception (yes/no): no

# %% [markdown]
# # # Model based agent

# %%
model = {'A':'Unknown', 'B':'Unknown'}
world_state = 'Conditon Bad'
action = 'Unknown'

def update_state(action, percept, model):
    location = percept[0]
    status = percept[1]
    model[location] = status #udate the model based on current perception
    
    global world_state
    if action == 'Carpeting':
        model[location]='Making'
    if model['A']=='Making' and model['B']=='Colour': # model checking
        world_state = 'Good'
    else:
        world_state = 'Condition Bad'
    return world_state
        

def model_based_reflex_agent(percept):
    location = percept[0]
    status = percept[1]
    
    global world_state,action,model
    
    if world_state == 'Good':
        action = 'Pause'
        return action
    elif status == 'Broken':
        action = 'Carpeting'
    elif location == 'A':
        action = 'Right'
    elif location == 'B':
        action = 'Left'
    world_state = update_state(action, percept, model)
    print('Perception: '+str(percept)) 
    print('Action Performed: '+ action)    
    print('Model: '+str(model))   
    print('State: '+str(world_state))    
    return action


import random
Location = random.choice(['A','B'])
Condition= random.choice(['Making','Broken'])

while True:
    print('*****')
    action = model_based_reflex_agent((Location,Condition))
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Making','Broken'])
    elif action == 'Left':
        Location = 'A'
        Condition = random.choice(['Making','Broken'])
    elif action == 'Carpeting':
        Condition = 'Making'
    elif action == 'Pause':
        cmd = input('Stopped. Do restart? (yes/no): ')
        if(cmd == 'no' or cmd != 'yes'): break
        Location = random.choice(['A','B'])
        Condition = random.choice(['Making','Broken'])
        model = {'A':'Unknown', 'B':'Unknown'}
        world_state = 'Condition Bad'
        action = 'Unknown'
# Out:
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Unknown', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Unknown', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# ...
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('A', 'Making')
# Action Performed: Right
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Broken')
# Action Performed: Carpeting
# Model: {'A': 'Making', 'B': 'Making'}
# State: Condition Bad
# *****
# Perception: ('B', 'Making')
# Action Performed: Left
# Model: {'A': 'Making', 'B': 'Making'}
